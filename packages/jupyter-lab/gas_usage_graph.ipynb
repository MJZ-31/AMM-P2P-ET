# %%
import matplotlib.pyplot as plt
import numpy as np

fig1, ax1 = plt.subplots(figsize=(6,4))
ax1.bar(np.arange(4), [81071, 107298, 88638, 155481], width=0.4, label="Buy")
ax1.bar(np.arange(4) + 0.4, [80938, 106571, 88616, 176815], width=0.4, label="Sell")
plt.legend()
ax1.axes.set_ylabel("Gas Usage")
plt.xticks(np.arange(4) + 0.2, ("CSMM", "CPMM", "CLMM", "Hybrid"))
plt.title("AMMs Gas Usage")
plt.savefig("gas_usage.pdf")
