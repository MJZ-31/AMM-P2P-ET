# %%
import csv
import matplotlib.pyplot as plt
import numpy as np

csmm_data = []
reader = csv.reader(open("CSMM_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    csmm_data.append([])
    for element in row:
        csmm_data[iRow].append(element)
    iRow += 1
csmm_data = csmm_data[2:]

csmm_poolPrice = [0] * len(csmm_data)
for iRow in range(0, len(csmm_data)):
    csmm_poolPrice[iRow] = float(csmm_data[iRow][len(row) - 1])

cpmm_data = []
reader = csv.reader(open("CPMM_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    cpmm_data.append([])
    for element in row:
        cpmm_data[iRow].append(element)
    iRow += 1
cpmm_data = cpmm_data[2:]

cpmm_poolPrice = [0] * len(cpmm_data)
for iRow in range(0, len(cpmm_data)):
    cpmm_poolPrice[iRow] = float(cpmm_data[iRow][len(row) - 1])

clmm_data = []
reader = csv.reader(open("CLMM_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    clmm_data.append([])
    for element in row:
        clmm_data[iRow].append(element)
    iRow += 1
clmm_data = clmm_data[2:]

clmm_poolPrice = [0] * len(clmm_data)
for iRow in range(0, len(clmm_data)):
    clmm_poolPrice[iRow] = float(clmm_data[iRow][len(row) - 1])

hybrid_curve_CSMM_fee_0_data = []
reader = csv.reader(open("hybrid_curve_CSMM_fee_0_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CSMM_fee_0_data.append([])
    for element in row:
        hybrid_curve_CSMM_fee_0_data[iRow].append(element)
    iRow += 1
hybrid_curve_CSMM_fee_0_data = hybrid_curve_CSMM_fee_0_data[2:]

hybrid_curve_CSMM_fee_0_poolPrice = [0] * len(hybrid_curve_CSMM_fee_0_data)
for iRow in range(0, len(hybrid_curve_CSMM_fee_0_data)):
    hybrid_curve_CSMM_fee_0_poolPrice[iRow] = float(hybrid_curve_CSMM_fee_0_data[iRow][len(row) - 1])

hybrid_curve_CSMM_fee_25_data = []
reader = csv.reader(open("hybrid_curve_CSMM_fee_25_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CSMM_fee_25_data.append([])
    for element in row:
        hybrid_curve_CSMM_fee_25_data[iRow].append(element)
    iRow += 1
hybrid_curve_CSMM_fee_25_data = hybrid_curve_CSMM_fee_25_data[2:]

hybrid_curve_CSMM_fee_25_poolPrice = [0] * len(hybrid_curve_CSMM_fee_25_data)
for iRow in range(0, len(hybrid_curve_CSMM_fee_25_data)):
    hybrid_curve_CSMM_fee_25_poolPrice[iRow] = float(hybrid_curve_CSMM_fee_25_data[iRow][len(row) - 1])

hybrid_curve_CSMM_fee_50_data = []
reader = csv.reader(open("hybrid_curve_CSMM_fee_50_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CSMM_fee_50_data.append([])
    for element in row:
        hybrid_curve_CSMM_fee_50_data[iRow].append(element)
    iRow += 1
hybrid_curve_CSMM_fee_50_data = hybrid_curve_CSMM_fee_50_data[2:]

hybrid_curve_CSMM_fee_50_poolPrice = [0] * len(hybrid_curve_CSMM_fee_50_data)
for iRow in range(0, len(hybrid_curve_CSMM_fee_50_data)):
    hybrid_curve_CSMM_fee_50_poolPrice[iRow] = float(hybrid_curve_CSMM_fee_50_data[iRow][len(row) - 1])

hybrid_curve_CSMM_fee_75_data = []
reader = csv.reader(open("hybrid_curve_CSMM_fee_75_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CSMM_fee_75_data.append([])
    for element in row:
        hybrid_curve_CSMM_fee_75_data[iRow].append(element)
    iRow += 1
hybrid_curve_CSMM_fee_75_data = hybrid_curve_CSMM_fee_75_data[2:]

hybrid_curve_CSMM_fee_75_poolPrice = [0] * len(hybrid_curve_CSMM_fee_75_data)
for iRow in range(0, len(hybrid_curve_CSMM_fee_75_data)):
    hybrid_curve_CSMM_fee_75_poolPrice[iRow] = float(hybrid_curve_CSMM_fee_75_data[iRow][len(row) - 1])

hybrid_curve_CSMM_fee_100_data = []
reader = csv.reader(open("hybrid_curve_CSMM_fee_100_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CSMM_fee_100_data.append([])
    for element in row:
        hybrid_curve_CSMM_fee_100_data[iRow].append(element)
    iRow += 1
hybrid_curve_CSMM_fee_100_data = hybrid_curve_CSMM_fee_100_data[2:]

hybrid_curve_CSMM_fee_100_poolPrice = [0] * len(hybrid_curve_CSMM_fee_100_data)
for iRow in range(0, len(hybrid_curve_CSMM_fee_100_data)):
    hybrid_curve_CSMM_fee_100_poolPrice[iRow] = float(hybrid_curve_CSMM_fee_100_data[iRow][len(row) - 1])

hybrid_curve_CPMM_fee_0_data = []
reader = csv.reader(open("hybrid_curve_CPMM_fee_0_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CPMM_fee_0_data.append([])
    for element in row:
        hybrid_curve_CPMM_fee_0_data[iRow].append(element)
    iRow += 1
hybrid_curve_CPMM_fee_0_data = hybrid_curve_CPMM_fee_0_data[2:]

hybrid_curve_CPMM_fee_0_poolPrice = [0] * len(hybrid_curve_CPMM_fee_0_data)
for iRow in range(0, len(hybrid_curve_CPMM_fee_0_data)):
    hybrid_curve_CPMM_fee_0_poolPrice[iRow] = float(hybrid_curve_CPMM_fee_0_data[iRow][len(row) - 1])

hybrid_curve_CPMM_fee_25_data = []
reader = csv.reader(open("hybrid_curve_CPMM_fee_25_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CPMM_fee_25_data.append([])
    for element in row:
        hybrid_curve_CPMM_fee_25_data[iRow].append(element)
    iRow += 1
hybrid_curve_CPMM_fee_25_data = hybrid_curve_CPMM_fee_25_data[2:]

hybrid_curve_CPMM_fee_25_poolPrice = [0] * len(hybrid_curve_CPMM_fee_25_data)
for iRow in range(0, len(hybrid_curve_CPMM_fee_25_data)):
    hybrid_curve_CPMM_fee_25_poolPrice[iRow] = float(hybrid_curve_CPMM_fee_25_data[iRow][len(row) - 1])

hybrid_curve_CPMM_fee_50_data = []
reader = csv.reader(open("hybrid_curve_CPMM_fee_50_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CPMM_fee_50_data.append([])
    for element in row:
        hybrid_curve_CPMM_fee_50_data[iRow].append(element)
    iRow += 1
hybrid_curve_CPMM_fee_50_data = hybrid_curve_CPMM_fee_50_data[2:]

hybrid_curve_CPMM_fee_50_poolPrice = [0] * len(hybrid_curve_CPMM_fee_50_data)
for iRow in range(0, len(hybrid_curve_CPMM_fee_50_data)):
    hybrid_curve_CPMM_fee_50_poolPrice[iRow] = float(hybrid_curve_CPMM_fee_50_data[iRow][len(row) - 1])

hybrid_curve_CPMM_fee_75_data = []
reader = csv.reader(open("hybrid_curve_CPMM_fee_75_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CPMM_fee_75_data.append([])
    for element in row:
        hybrid_curve_CPMM_fee_75_data[iRow].append(element)
    iRow += 1
hybrid_curve_CPMM_fee_75_data = hybrid_curve_CPMM_fee_75_data[2:]

hybrid_curve_CPMM_fee_75_poolPrice = [0] * len(hybrid_curve_CPMM_fee_75_data)
for iRow in range(0, len(hybrid_curve_CPMM_fee_75_data)):
    hybrid_curve_CPMM_fee_75_poolPrice[iRow] = float(hybrid_curve_CPMM_fee_75_data[iRow][len(row) - 1])

hybrid_curve_CPMM_fee_100_data = []
reader = csv.reader(open("hybrid_curve_CPMM_fee_100_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CPMM_fee_100_data.append([])
    for element in row:
        hybrid_curve_CPMM_fee_100_data[iRow].append(element)
    iRow += 1
hybrid_curve_CPMM_fee_100_data = hybrid_curve_CPMM_fee_100_data[2:]

hybrid_curve_CPMM_fee_100_poolPrice = [0] * len(hybrid_curve_CPMM_fee_100_data)
for iRow in range(0, len(hybrid_curve_CPMM_fee_100_data)):
    hybrid_curve_CPMM_fee_100_poolPrice[iRow] = float(hybrid_curve_CPMM_fee_100_data[iRow][len(row) - 1])

hybrid_curve_CLMM_fee_0_data = []
reader = csv.reader(open("hybrid_curve_CLMM_fee_0_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CLMM_fee_0_data.append([])
    for element in row:
        hybrid_curve_CLMM_fee_0_data[iRow].append(element)
    iRow += 1
hybrid_curve_CLMM_fee_0_data = hybrid_curve_CLMM_fee_0_data[2:]

hybrid_curve_CLMM_fee_0_poolPrice = [0] * len(hybrid_curve_CLMM_fee_0_data)
for iRow in range(0, len(hybrid_curve_CLMM_fee_0_data)):
    hybrid_curve_CLMM_fee_0_poolPrice[iRow] = float(hybrid_curve_CLMM_fee_0_data[iRow][len(row) - 1])

hybrid_curve_CLMM_fee_25_data = []
reader = csv.reader(open("hybrid_curve_CLMM_fee_25_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CLMM_fee_25_data.append([])
    for element in row:
        hybrid_curve_CLMM_fee_25_data[iRow].append(element)
    iRow += 1
hybrid_curve_CLMM_fee_25_data = hybrid_curve_CLMM_fee_25_data[2:]

hybrid_curve_CLMM_fee_25_poolPrice = [0] * len(hybrid_curve_CLMM_fee_25_data)
for iRow in range(0, len(hybrid_curve_CLMM_fee_25_data)):
    hybrid_curve_CLMM_fee_25_poolPrice[iRow] = float(hybrid_curve_CLMM_fee_25_data[iRow][len(row) - 1])

hybrid_curve_CLMM_fee_50_data = []
reader = csv.reader(open("hybrid_curve_CLMM_fee_50_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CLMM_fee_50_data.append([])
    for element in row:
        hybrid_curve_CLMM_fee_50_data[iRow].append(element)
    iRow += 1
hybrid_curve_CLMM_fee_50_data = hybrid_curve_CLMM_fee_50_data[2:]

hybrid_curve_CLMM_fee_50_poolPrice = [0] * len(hybrid_curve_CLMM_fee_50_data)
for iRow in range(0, len(hybrid_curve_CLMM_fee_50_data)):
    hybrid_curve_CLMM_fee_50_poolPrice[iRow] = float(hybrid_curve_CLMM_fee_50_data[iRow][len(row) - 1])

hybrid_curve_CLMM_fee_75_data = []
reader = csv.reader(open("hybrid_curve_CLMM_fee_75_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CLMM_fee_75_data.append([])
    for element in row:
        hybrid_curve_CLMM_fee_75_data[iRow].append(element)
    iRow += 1
hybrid_curve_CLMM_fee_75_data = hybrid_curve_CLMM_fee_75_data[2:]

hybrid_curve_CLMM_fee_75_poolPrice = [0] * len(hybrid_curve_CLMM_fee_75_data)
for iRow in range(0, len(hybrid_curve_CLMM_fee_75_data)):
    hybrid_curve_CLMM_fee_75_poolPrice[iRow] = float(hybrid_curve_CLMM_fee_75_data[iRow][len(row) - 1])

hybrid_curve_CLMM_fee_100_data = []
reader = csv.reader(open("hybrid_curve_CLMM_fee_100_simulation_data.csv", newline=""), delimiter=",", quotechar="*")
iRow = 0
for row in reader:
    hybrid_curve_CLMM_fee_100_data.append([])
    for element in row:
        hybrid_curve_CLMM_fee_100_data[iRow].append(element)
    iRow += 1
hybrid_curve_CLMM_fee_100_data = hybrid_curve_CLMM_fee_100_data[2:]

hybrid_curve_CLMM_fee_100_poolPrice = [0] * len(hybrid_curve_CLMM_fee_100_data)
for iRow in range(0, len(hybrid_curve_CLMM_fee_100_data)):
    hybrid_curve_CLMM_fee_100_poolPrice[iRow] = float(hybrid_curve_CLMM_fee_100_data[iRow][len(row) - 1])

# %%
fig1, ax1 = plt.subplots(figsize=(6,4))
ax1.plot(range(1, 49), csmm_poolPrice[:48], label="CSMM", color="tab:blue", marker="*")
ax1.plot(range(1, 49), cpmm_poolPrice[:48], label="CPMM", color="tab:red", marker="*")
ax1.plot(range(1, 49), clmm_poolPrice[:48], label="CLMM", color="tab:green", marker="*")
ax1.legend()
ax1.axes.set_ylabel("Pool Price (USDC/ETK)")
ax1.axes.set_xlabel("Simulation Hour")
for label in ax1.get_xticklabels():
    label.set_rotation(45)
plt.xticks(np.arange(0, 49, 2))
plt.title("EnergyAMM Simulation Curve Comparison")
plt.tight_layout()
plt.savefig("simulation_curve_comparison.pdf")

# %%
fig1, ax1 = plt.subplots(figsize=(6,4))
ax1.plot(range(1, 49), hybrid_curve_CSMM_fee_100_poolPrice[:48], label="100% Fee", color="tab:orange", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CSMM_fee_75_poolPrice[:48], label="75% Fee", color="tab:purple", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CSMM_fee_50_poolPrice[:48], label="50% Fee", color="tab:blue", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CSMM_fee_25_poolPrice[:48], label="25% Fee", color="tab:red", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CSMM_fee_0_poolPrice[:48], label="No Fee", color="tab:green", marker="*")
ax1.legend()
ax1.axes.set_ylabel("Pool Price (USDC/ETK)")
ax1.axes.set_xlabel("Simulation Hour")
for label in ax1.get_xticklabels():
    label.set_rotation(45)
plt.xticks(np.arange(0, 49, 2))
plt.title("EnergyAMM Simulation CSMM Fee Rate Comparison")
plt.tight_layout()
plt.savefig("simulation_CSMM_fee_comparison.pdf")

# %%
fig1, ax1 = plt.subplots(figsize=(6,4))
ax1.plot(range(1, 49), hybrid_curve_CPMM_fee_100_poolPrice[:48], label="100% Fee", color="tab:orange", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CPMM_fee_75_poolPrice[:48], label="75% Fee", color="tab:purple", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CPMM_fee_50_poolPrice[:48], label="50% Fee", color="tab:blue", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CPMM_fee_25_poolPrice[:48], label="25% Fee", color="tab:red", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CPMM_fee_0_poolPrice[:48], label="No Fee", color="tab:green", marker="*")
ax1.legend()
ax1.axes.set_ylabel("Pool Price (USDC/ETK)")
ax1.axes.set_xlabel("Simulation Hour")
for label in ax1.get_xticklabels():
    label.set_rotation(45)
plt.xticks(np.arange(0, 49, 2))
plt.title("EnergyAMM Simulation CPMM Fee Rate Comparison")
plt.tight_layout()
plt.savefig("simulation_CPMM_fee_comparison.pdf")

# %%
fig1, ax1 = plt.subplots(figsize=(6,4))
ax1.plot(range(1, 49), hybrid_curve_CLMM_fee_100_poolPrice[:48], label="100% Fee", color="tab:orange", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CLMM_fee_75_poolPrice[:48], label="75% Fee", color="tab:purple", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CLMM_fee_50_poolPrice[:48], label="50% Fee", color="tab:blue", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CLMM_fee_25_poolPrice[:48], label="25% Fee", color="tab:red", marker="*")
ax1.plot(range(1, 49), hybrid_curve_CLMM_fee_0_poolPrice[:48], label="No Fee", color="tab:green", marker="*")
ax1.legend()
ax1.axes.set_ylabel("Pool Price (USDC/ETK)")
ax1.axes.set_xlabel("Simulation Hour")
for label in ax1.get_xticklabels():
    label.set_rotation(45)
plt.xticks(np.arange(0, 49, 2))
plt.title("EnergyAMM Simulation CLMM Fee Rate Comparison")
plt.tight_layout()
plt.savefig("simulation_CLMM_fee_comparison.pdf")
